# %%
from getdist import plots
import getdist

# %% [markdown]
# # Test de base

# %%
path = "C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/"
testrun=getdist.loadMCSamples(path+'base_config_test',
                              #settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
# Out:
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\base_config_test.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\base_config_test.2.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\base_config_test.3.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\base_config_test.4.txt
# Removed no burn in

# %%
samples = [testrun]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes

# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["testrun"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["red"],
    title_limit=1,
    markers={"x2": 0},
)

# g.export('testrun_triangle.pdf')
# Out:
# WARNING:root:fine_bins not large enough to well sample smoothing scale - chi2
# WARNING:root:fine_bins not large enough to well sample smoothing scale - chi2__planck_number_counts_vRUN_t3.NumberCounts

# %%
samples = [testrun]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=15)

# Pour faire joli
g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.4
g.settings.title_limit_fontsize = 14
g.settings.legend_fontsize = 13
g.settings.axes_labelsize = 16

# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "alpha_sz", "logystar_sz", "bias_sz", "scatter_sz"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["testrun"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["red"],
    title_limit=1,
    markers={"x2": 0},
)

# g.export('testrun_triangle.pdf')

# %%
# Plot de tous les paramètres cosmo

samples = [testrun]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=15)

# Pour faire joli
g.settings.figure_legend_frame = False
g.settings.alpha_filled_add = 0.4
g.settings.title_limit_fontsize = 14
g.settings.legend_fontsize = 13
g.settings.axes_labelsize = 16

# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","tau","H0"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["testrun"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["red"],
    title_limit=1,
    markers={"x2": 0},
)

# g.export('testrun_triangle.pdf')

# %% [markdown]
# # Test Figure 7 de Planck 2015

# %%
path = "C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/"
run1=getdist.loadMCSamples(path+'config_bias1',
                              settings={'ignore_rows':0.5} # Pour ignorer les 30% premières lignes
)
run2=getdist.loadMCSamples(path+'config_bias2',
                              settings={'ignore_rows':0.5} # Pour ignorer les 30% premières lignes
)
run3=getdist.loadMCSamples(path+'config_bias3',
                              settings={'ignore_rows':0.5} # Pour ignorer les 30% premières lignes
)
run4=getdist.loadMCSamples(path+'config_bias4',
                              settings={'ignore_rows':0.5} # Pour ignorer les 30% premières lignes
)
# Out:
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias1.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias1.2.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias1.3.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias1.4.txt
# Removed 0.5 as burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias2.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias2.2.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias2.3.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias2.4.txt
# Removed 0.5 as burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias3.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias3.2.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias3.3.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_bias3.4.txt
# Removed 0.5 as burn in
# ...

# %%
samples = [run1,run2,run3]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["WtG","CCCP", "CMBlens"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["green", "blue", "red"],
    title_limit=1,
    markers={"x2": 0},
)


g.export('testrun_triangle.pdf')
