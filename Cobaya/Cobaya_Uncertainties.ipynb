# %%
from getdist import plots
import getdist

# %% [markdown]
# # En réduisant l'incertitude sur $b$ et $\alpha$ séparément

# %%
path = "C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/"
run_normal = getdist.loadMCSamples(path+'Old/config_bias2',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
run_b1=getdist.loadMCSamples(path+'config_b_uncertainty_1',
                            #   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
run_b2=getdist.loadMCSamples(path+'config_b_uncertainty_2',
                            #   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
run_a1=getdist.loadMCSamples(path+'config_alpha_uncertainty_2',
                              settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
run_a2=getdist.loadMCSamples(path+'config_alpha_uncertainty_4',
                              settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
# Out:
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_1.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_1.2.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_1.3.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_1.4.txt
# Removed no burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_2.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_2.2.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_2.3.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_b_uncertainty_2.4.txt
# Removed no burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_alpha_uncertainty_2.1.txt
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data\config_alpha_uncertainty_2.2.txt
# ...

# %% [markdown]
# ### Sur $b$

# %%
samples = [run_normal, run_b1,run_b2]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8"],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$\sigma_b = 0,092$", r"$\sigma_b = 0.046$", r"$\sigma_b = 0.023$"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('b_uncertainty.pdf')

# %% [markdown]
# - Valeurs des incertitudes sur Omega_m: 0,021; 0,020; 0,0195
#     => Variations à peu près nulles
# - Valeurs des incertitudes sur sigma_8: 0,0305; 0,020; 0,016
#     => Variation de 34% pour le /2, variation de 48% pour le /4
# - Diviser l'incertitude sur $b$ par 4 apporte moins par rapport à diviser par 2. Mais ça vaut quand même le coup, contrairement à alpha => b est vraiment un paramètre limitant en termes d'incertitudes ajd.
# - Léger shift des paramètres cosmologiques (CARACTERISER EN TERMES DE 1 $\sigma$, 2 $\sigma$, ... )
#
# <FONT color="#FF0000"> <B> Calculer  FMs : 1/(sigma_a * sigma_b), ou avec les sigmas relatifs: sigma_a/a et sigma_b/b</B></FONT>

# %% [markdown]
# ### Sur $\alpha$

# %%
samples = [run_normal, run_a1,run_a2]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8"],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$\sigma_{\alpha} = 0,08$", r"$\sigma_{\alpha} = 0,04$", r"$\sigma_{\alpha} = 0,02$"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('alpha_uncertainty.pdf')

# %% [markdown]
# - Valeurs des incertitudes sur Omega_m: 0,021; 0,015; 0,014
#     => variation de 29 %
# - Diviser l'incertitude sur $\alpha$ par 4 n'apporte quasiment rien par rapport à diviser par 2.
# Cela est certainement dû au fait que l'incertitude sur $\alpha$ devient négligeable devant une autre incertitude.
# Ainsi, réduire l'incertitude sur alpha est intéressant jusqu'à un certain point
# - Léger shift des paramètres cosmologiques (CARACTERISER EN TERMES DE 1 $\sigma$, 2 $\sigma$, ... => <FONT color="#FF0000"> <B> COMMENT FAIRE ?</B></FONT>)

# %% [markdown]
# # En réduisant en même temps

# %%
path = "C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/"
run_normal = getdist.loadMCSamples(path+'Old/config_bias2',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
run_ba22=getdist.loadMCSamples(path+'config_balpha_uncertainty_22',
                              settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
run_ba44=getdist.loadMCSamples(path+'config_balpha_uncertainty_44',
                              settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

# %%
samples = [run_normal, run_ba22,run_ba44]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8"],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$\sigma_b = 0,092; \: \sigma_{\alpha} = 0,08$", r"$\sigma_b = 0,046; \: \sigma_{\alpha} = 0,04$", r"$\sigma_b = 0,023; \: \sigma_{\alpha} = 0,02$"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('balpha_uncertainty.pdf')
