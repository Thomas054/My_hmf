# %%
from getdist import plots
import getdist
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = "C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8/"

# %% [markdown]
# # 1

# %%
run1_lmax1100 = getdist.loadMCSamples(path+'1_biasfree_P0fixed_lmax1100',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

run1 = getdist.loadMCSamples(path+'1_biasfree_P0fixed',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

# %%
samples = [run1_lmax1100, run1]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["lmax1100","l pas borné"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('1.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_log10Mc very small or failed (h=0.0004500066382572533,N_eff=957.8303791417978). Using fallback (h=0.10065115994972998)
# WARNING:root:auto bandwidth for bar_gamma very small or failed (h=0.00040885964577455343,N_eff=866.5615143548805). Using fallback (h=0.0994043152616708)
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.00039689498521126756,N_eff=889.9911900641105). Using fallback (h=0.10166364526687942)
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for logA, bias_sz. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# # 2

# %%
run2_lmax1100 = getdist.loadMCSamples(path+'2_P0free_biasfixed_lmax1100',
                                   settings={'ignore_rows':0.5} # Pour ignorer les 30% premières lignes
)

run2 = getdist.loadMCSamples(path + '2_P0free_biasfixed',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
# Out:
# WARNING:root:outlier fraction 0.00032
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\2_P0free_biasfixed_lmax1100.1.txt
# Removed 0.5 as burn in
# WARNING:root:outlier fraction 0.0007197351374694113
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\2_P0free_biasfixed.1.txt
# Removed 0.3 as burn in

# %% [markdown]
# ## Comparaison lmax1100 et l pas borné

# %%
samples = [run2_lmax1100, run2]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# for s in samples:
#     s.updateSettings({'smooth_scale_2D': 0.8})  # Pour lisser les contours


# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "pp_P0"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["lmax1100","l pas borné"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('2.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_mu very small or failed (h=0.00044423245715977843,N_eff=1188.0154318465463). Using fallback (h=0.09624756210745919)
# WARNING:root:auto bandwidth for bar_gamma very small or failed (h=0.000440484132633306,N_eff=1184.5365151973972). Using fallback (h=0.09347541554966356)
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, H0. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# ## Comparaison avec 1

# %% [markdown]
# ### lmax1100

# %%
samples = [run1_lmax1100, run2_lmax1100]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["bias free","P0 free"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('1-2_lmax1100.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.0004995241574695205,N_eff=1422.2240427680288). Using fallback (h=0.08958766848804735)
# WARNING:root:auto bandwidth for bar_eta very small or failed (h=0.0005331216642891442,N_eff=1351.3067181712297). Using fallback (h=0.09085235871186599)

# %% [markdown]
# ### lmax10000

# %%
samples = [run1, run2]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# for s in samples:
#     s.updateSettings({'smooth_scale_2D': 0.8})  # Pour lisser les contours

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz", "pp_P0"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["bias free","P0 free"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('1-2.pdf')

# %% [markdown]
# ## Tests et essais (inutile maintenant)

# %%
column_names = ["weight","minuslogpost","cosmomc_theta","logA","ns","ombh2","omch2","pp_P0","bar_log10Mc","bar_mu","bar_thej","bar_gamma","bar_delta","bar_eta","bar_deta","As","sigma8","omegam","H0","chi2__BAO","minuslogprior","minuslogprior__0","minuslogprior__prior_ns","minuslogprior__prior_ombh2","chi2","chi2__planck_power_spectrum_batPP.PowerSpectrum_pp","chi2__bao.sdss_dr12_consensus_bao"]
data = pd.read_csv(path + '2_P0free_biasfixed.1.txt', delim_whitespace=True, skiprows=1, header=None, names=column_names)
data_lmax1100 = pd.read_csv(path + '2_P0free_biasfixed_lmax1100.1.txt', delim_whitespace=True, skiprows=1, header=None, names=column_names)

logA = data["logA"].values
ns = data["ns"].values
ombh2 = data["ombh2"].values
omch2 = data["omch2"].values
P0 = data["pp_P0"].values

logA_lmax1100 = data_lmax1100["logA"].values
ns_lmax1100 = data_lmax1100["ns"].values
ombh2_lmax1100 = data_lmax1100["ombh2"].values
omch2_lmax1100 = data_lmax1100["omch2"].values
P0_lmax1100 = data_lmax1100["pp_P0"].values


Om = data["omegam"].values
Om_lmax1100 = data_lmax1100["omegam"].values
sigma8 = data["sigma8"].values
sigma8_lmax1100 = data_lmax1100["sigma8"].values

# %% [markdown]
# ### Progression du run

# %%
plt.plot(logA_lmax1100, color="k", label="lmax1100")
plt.plot(logA, color="b", label="l pas borné")
plt.title("logA")
plt.xlabel("Itérations")
plt.ylabel("logA")
plt.legend()
plt.show()

plt.plot(ns_lmax1100, color="k", label="lmax1100")
plt.plot(ns, color="b", label="l pas borné")
plt.title("ns")
plt.xlabel("Itérations")
plt.ylabel("ns")
plt.legend()
plt.show()

plt.plot(ombh2_lmax1100, color="k", label="lmax1100")
plt.plot(ombh2, color="b", label="l pas borné")
plt.title("ombh2")
plt.xlabel("Itérations")
plt.ylabel("ombh2")
plt.legend()
plt.show()

plt.plot(omch2_lmax1100, color="k", label="lmax1100")
plt.plot(omch2, color="b", label="l pas borné")
plt.title("omch2")
plt.xlabel("Itérations")
plt.ylabel("omch2")
plt.legend()
plt.show()

plt.plot(P0_lmax1100, color="k", label="lmax1100")
plt.plot(P0, color="b", label="l pas borné")
plt.title("P0")
plt.xlabel("Itérations")
plt.ylabel("P0")
plt.legend()
plt.show()

plt.plot(Om_lmax1100, color="k", label="lmax1100")
plt.plot(Om, color="b", label="l pas borné")
plt.title("Om")
plt.xlabel("Itérations")
plt.ylabel("Om")
plt.legend()
plt.show()

# %% [markdown]
# ### Plot 2D sans getdist

# %%
plt.plot(Om_lmax1100, sigma8_lmax1100, 'o', color="k", label="lmax1100", markersize=1)
plt.plot(Om, sigma8, 'o', color="b", label="l pas borné", markersize=1)
plt.xlabel("Om")
plt.ylabel("sigma8")
plt.title("Om vs sigma8")
plt.legend()
plt.show()

# %% [markdown]
# # 3

# %%
run3_lmax1100 = getdist.loadMCSamples(path+'3_betafree_lmax1100',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

run3 = getdist.loadMCSamples(path+'3_betafree',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

# %% [markdown]
# ## Comparaison lmax1100 et lmax10000

# %%
samples = [run3_lmax1100, run3]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "pp_beta",
      "omch2","ombh2","ns","logA","H0", "bias_sz"
    ],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$\ell_{max}=1100$",r"$\ell_{max}=10000$"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('3.pdf')

# %% [markdown]
# ## Comparaison 1 et 3

# %% [markdown]
# ### lmax1100

# %%
samples = [run1_lmax1100, run3_lmax1100]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz", "pp_beta"],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$\beta$ fixé",r"$\beta$ libre"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('3-1_lmax1100.pdf')

# %% [markdown]
# ### lmax10000

# %%
samples = [run1, run3]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz", "pp_beta"],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$\beta$ fixé",r"$\beta$ libre"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('3-1.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_log10Mc very small or failed (h=0.0004500066382572533,N_eff=957.8303791417978). Using fallback (h=0.10065115994972998)
# WARNING:root:auto bandwidth for bar_gamma very small or failed (h=0.00040885964577455343,N_eff=866.5615143548805). Using fallback (h=0.0994043152616708)
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.00039689498521126756,N_eff=889.9911900641105). Using fallback (h=0.10166364526687942)
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for logA, bias_sz. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# # 4

# %%
run4_lmax1100 = getdist.loadMCSamples(path+'4_rangefb_DMonly_lmax1100',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

run4 = getdist.loadMCSamples(path+'4_rangefb_DMonly',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
# Out:
# WARNING:root:outlier fraction 0.00011212857409829938
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\4_rangefb_DMonly_lmax1100.1.txt
# Removed 0.3 as burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\4_rangefb_DMonly.1.txt
# WARNING:root:outlier fraction 0.0004157016449907952
# Removed 0.3 as burn in

# %% [markdown]
# ## Comparaison lmax1100 et l pas borné

# %%
samples = [run4_lmax1100, run4]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["lmax1100","l pas borné"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('4.pdf')

# %% [markdown]
# ## Comparaison 1 et 4

# %% [markdown]
# ### lmax1100

# %%
samples = [run1_lmax1100, run4_lmax1100]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
    #  "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$f_b$ non contraint",r"$f_b$ contraint"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)

# g.fig.suptitle(r"Comparaison avec et sans fb contraint avec $\ell_{max} = 1100$")

g.export('4-1_lmax1100.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.0004995241574695205,N_eff=1422.2240427680288). Using fallback (h=0.08958766848804735)
# WARNING:root:auto bandwidth for bar_eta very small or failed (h=0.0005331216642891442,N_eff=1351.3067181712297). Using fallback (h=0.09085235871186599)

# %% [markdown]
# ### lmax10000

# %%
samples = [run1, run4]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
    #  "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    legend_labels=[r"$f_b$ non contraint",r"$f_b$ contraint"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)

# g.fig.suptitle(r"Comparaison avec et sans fb contraint avec $\ell_{max} = 10000$")

g.export('4-1.pdf')

# %% [markdown]
# # 5

# %%
run5_lmax1100 = getdist.loadMCSamples(path+'5_rangefb_baryonification_lmax1100',
                                   settings={'ignore_rows':0.5} # Pour ignorer les 30% premières lignes
)

run5 = getdist.loadMCSamples(path+'5_rangefb_baryonification',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
# Out:
# WARNING:root:outlier fraction 0.0003582303421099767
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\5_rangefb_baryonification_lmax1100.1.txt
# Removed 0.5 as burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\5_rangefb_baryonification.1.txt
# Removed 0.3 as burn in
# WARNING:root:outlier fraction 0.00022401433691756272

# %% [markdown]
# ## Comparaison lmax1100 et lmax10000

# %%
samples = [run5_lmax1100, run5]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["lmax1100","lmax10000"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('5.pdf')

# %% [markdown]
# ## Comparaison 4 et 5

# %% [markdown]
# ### lmax1100

# %%
samples = [run4_lmax1100, run5_lmax1100]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
     "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    
    legend_labels=["Sans baryonification","Avec baryonification"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)
g.fig.suptitle(r"Comparaison avec et sans baryonification avec $\ell_{max} = 1100$")

g.export('4-5_lmax1100.pdf')

# %% [markdown]
# ### lmax10000

# %%
samples = [run4, run5]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
     "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    legend_labels=["Sans baryonification","Avec baryonification"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)

g.fig.suptitle(r"Comparaison avec et sans baryonification avec $\ell_{max} = 10000$")

g.export('4-5.pdf')

# %% [markdown]
# ### Tout d'un coup

# %%
samples = [run4_lmax1100, run4, run5_lmax1100, run5]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
    #  "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    legend_labels=["Sans baryons, lmax=1100","Sans baryons, lmax=10000","Avec baryons, lmax=1100", "Avec baryons, lmax=10000"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red", "green"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)

# g.fig.suptitle(r"Comparaison avec et sans baryonification avec $\ell_{max} = 10000$")

g.export('4-5_all.pdf')

# %% [markdown]
# ## Comparaison 1, 4 et 5

# %% [markdown]
# ### lmax = 1100

# %%
samples = [run1_lmax1100, run4_lmax1100, run5_lmax1100]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
     "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    
    legend_labels=["Sans contrainte sur fb","Avec contrainte sur fb, sans baryonification", "Avec contrainte sur fb, avec baryonification"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)
# g.fig.suptitle(r"Comparaison avec et sans baryonification avec $\ell_{max} = 1100$")

# g.export('4-5_lmax1100.pdf')

# %% [markdown]
# ### lmax = 10000

# %%
samples = [run1, run4, run5]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8",
     "omch2","ombh2","ns","logA","H0", "bias_sz"
     ],   # Paramètres à afficher
    filled=[True],
    
    legend_labels=["Sans contrainte sur fb","Avec contrainte sur fb, sans baryonification", "Avec contrainte sur fb, avec baryonification"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue", "red"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)
# g.fig.suptitle(r"Comparaison avec et sans baryonification avec $\ell_{max} = 1100$")

# g.export('4-5_lmax1100.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_log10Mc very small or failed (h=0.0004500066382572533,N_eff=957.8303791417978). Using fallback (h=0.10065115994972998)
# WARNING:root:auto bandwidth for bar_gamma very small or failed (h=0.00040885964577455343,N_eff=866.5615143548805). Using fallback (h=0.0994043152616708)
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.00039689498521126756,N_eff=889.9911900641105). Using fallback (h=0.10166364526687942)
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for logA, bias_sz. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# # 6

# %%
run6_lmax1100 = getdist.loadMCSamples(path+'6_rangefb_baryonification_deltafree_lmax1100',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)

run6 = getdist.loadMCSamples(path+'6_rangefb_baryonification_deltafree',
                                   settings={'ignore_rows':0.3} # Pour ignorer les 30% premières lignes
)
# Out:
# WARNING:root:outlier fraction 0.0007293946024799417
# WARNING:root:outlier fraction 0.0017341040462427746
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\6_rangefb_baryonification_deltafree_lmax1100.1.txt
# Removed 0.3 as burn in
# C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8\6_rangefb_baryonification_deltafree.1.txt
# Removed 0.3 as burn in

# %% [markdown]
# ## Comparaison lmax1100 et lmax10000

# %%
samples = [run6_lmax1100, run6]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz", "bar_delta"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["lmax1100","lmax10000"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('6.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.0007172619992451599,N_eff=23.9696242134333). Using fallback (h=0.13573896185297746)
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, sigma8. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, ombh2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, ns. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, bias_sz. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, ombh2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for ombh2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for ombh2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for logA, H0. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# ## Comparaison 4 et 6

# %% [markdown]
# ### lmax1100

# %%
samples = [run4_lmax1100, run6_lmax1100]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz", "bar_delta"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["Sans baryons","Avec baryons"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('4-6_lmax1100.pdf')

# %%
samples = [run4, run6]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["omegam", "sigma8", "omch2","ombh2","ns","logA","H0", "bias_sz", "bar_delta"],   # Paramètres à afficher
    filled=[True],
    legend_labels=["Sans baryons","Avec baryons"],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)


g.export('4-6.pdf')
# Out:
# WARNING:root:auto bandwidth for bar_delta very small or failed (h=0.0007172619992451599,N_eff=23.9696242134333). Using fallback (h=0.13573896185297746)
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, sigma8. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegam, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, omch2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, ombh2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, ns. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for sigma8, bias_sz. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, ombh2. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omch2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for ombh2, logA. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for ombh2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for logA, H0. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# # Tous les paramètres d'entrée (ceux avec un prior dans le yaml)

# %%
samples = [run4]  # Liste des échantillons auxquels on s'intéresse
g = plots.get_single_plotter(chain_dir=path, width_inch=9)  # width_inch = largeur de la figure

# Pour faire joli
g.settings.figure_legend_frame = False  # Cadre autour de la légende
g.settings.alpha_filled_add = 0.4   # ?
g.settings.title_limit_fontsize = 14    # Taille de la police du titre
g.settings.legend_fontsize = 13   # Taille de la police de la légende
g.settings.axes_labelsize = 16  # Taille de la police des labels des axes
# g.settings.xtick.labelsize = 14
# g.settings.ytick.labelsize = 14



# Plot
g.triangle_plot(
    samples,
    ["cosmomc_theta", "omch2","ombh2","ns","logA", "bias_sz"],   # Paramètres à afficher
    filled=[True],
    legend_labels=[],  # 1 label par sample
    legend_loc="upper right",   # Position de la légende
    contour_colors=["black", "blue"],  # Couleurs des contours
    title_limit=1,
    markers={"x2": 0},
)

# %% [markdown]
# # Courbes tSZ

# %%
path_tSZ = "C:/Users/thoma/Docs/Parcours_recherche/Code/Cobaya_data/Soutenance_S8/Courbes_tSZ/"
column_names = ['ell', 'Cll', 'Tll', 'sigma_Tll']
data4_lmax1100 = pd.read_csv(path_tSZ + '4_lmax1100.txt', delim_whitespace=True, header=None, names=column_names)
data4 = pd.read_csv(path_tSZ + '4.txt', delim_whitespace=True, header=None, names=column_names)
data5_lmax1100 = pd.read_csv(path_tSZ + '5_lmax1100.txt', delim_whitespace=True, header=None, names=column_names)
data5 = pd.read_csv(path_tSZ + '5.txt', delim_whitespace=True, header=None, names=column_names)

# %% [markdown]
# ## 4

# %%
plt.plot(data4_lmax1100['ell'], data4_lmax1100['Cll'], color="black", label="Sans baryons, lmax1100")
plt.plot(data4['ell'], data4['Cll'], color="blue", label="Sans baryons, lmax10000")
plt.plot(data5_lmax1100['ell'], data5_lmax1100['Cll'], color="red", label="Avec baryons, lmax1100")
plt.plot(data5['ell'], data5['Cll'], color="green", label="Avec baryons, lmax10000")
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\ell$', size=14)
plt.ylabel(r'$C_{\ell}$', size=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
